# %% [markdown]
# # Coolste document ter werled
# Hallo, mijn naam is **Binkie de Beer** en ik houd van eten! Mijn favoriete gerechten zijn:
#
# - Gebakken vis;
# - Gebraden vis;
# - Gepofte vis met veel pindasaus;
#
# ## Wat ik hier doe
# Ik ben een programmeur! Dit doe ik voornamelijk omdat ik intelligent ben. Kijk maar!
#
# 1. Ik kan Python programmeren;
# 2. Ik kan HTML schrijven;
# 3. Ik kan Markdown schrijven;
# 4. Ik kan vier dingen opsommen!
#
# Ik ben de intelligentste beer die je ooit in je leven zult tegenkomen! Geloof je me niet? [Google het maar](https://google.com/), dan zul je het zelf zien!

# %%
print("Wauw!")
# Out:
# Wauw!
